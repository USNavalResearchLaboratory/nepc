# %%
from nepc.util import config
from nepc.util import util
from nepc.util import parser
import nepc
import numpy as np
import re
import pandas as pd

# %%
NEPC_HOME = config.nepc_home()
outdir = NEPC_HOME + "/tests/data/cs/n2/fict_total"

# %%
util.rmdir(outdir)
util.mkdir(outdir)

# %%
debug = False

# %%
if debug:
    next_cs_id, next_csdata_id = (27, 578)
else:
    next_cs_id, next_csdata_id = parser.get_next_ids(test=True)

# %%
next_cs_id
# Out:
# 28

# %%
next_csdata_id
# Out:
# 579

# %%
pd.set_option('max_colwidth', 100)

# %%
cnx, cursor = nepc.connect(local=True, test=True)

# %%
def log_interp(zz, xx, yy):
    logz = np.log10(zz)
    logx = np.log10(xx)
    logy = np.log10(yy)
    return np.power(10.0, np.interp(logz, logx, logy, right=-1000.0))

# %%
n_fict_excitation_e_j = nepc.CustomModel(cursor, "fict", filter={'process': 'excitation'})

# %%
n_fict_excitation_e_j.summary()
# Out:
# Number of cross sections in model: 15
# <style  type="text/css" >
#     #T_44628e1e_99ea_11ea_86fd_acde48001122row0_col6 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row0_col7 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row0_col8 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row0_col9 {
#             background-color:  #f0f921;
#             color:  #000000;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row0_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row0_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row1_col6 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row1_col7 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row1_col8 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row1_col9 {
#             background-color:  #b12a90;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row1_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row1_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row2_col6 {
#             background-color:  #c5407e;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row2_col7 {
#             background-color:  #7a02a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row2_col8 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row2_col9 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row2_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row2_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row3_col6 {
#             background-color:  #d45270;
#             color:  #000000;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row3_col7 {
#             background-color:  #7a02a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row3_col8 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row3_col9 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row3_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row3_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row4_col6 {
#             background-color:  #da5a6a;
#             color:  #000000;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row4_col7 {
#             background-color:  #5e01a6;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row4_col8 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row4_col9 {
#             background-color:  #1d068e;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row4_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row4_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row5_col6 {
#             background-color:  #da5a6a;
#             color:  #000000;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row5_col7 {
#             background-color:  #7a02a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row5_col8 {
#             background-color:  #3f049c;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row5_col9 {
#             background-color:  #220690;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row5_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row5_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row6_col6 {
#             background-color:  #e16462;
#             color:  #000000;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row6_col7 {
#             background-color:  #8004a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row6_col8 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row6_col9 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row6_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row6_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row7_col6 {
#             background-color:  #e66c5c;
#             color:  #000000;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row7_col7 {
#             background-color:  #7201a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row7_col8 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row7_col9 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row7_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row7_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row8_col6 {
#             background-color:  #e97257;
#             color:  #000000;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row8_col7 {
#             background-color:  #7201a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row8_col8 {
#             background-color:  #5502a4;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row8_col9 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row8_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_44628e1e_99ea_11ea_86fd_acde48001122row8_col11 {

# %%
n_fict_excitation_e = n_fict_excitation_e_j.cs[2:]

# %%
for cs in n_fict_excitation_e:
    print('cs_id: {}'.format(cs.metadata['cs_id']))
# Out:
# cs_id: 13
# cs_id: 14
# cs_id: 15
# cs_id: 16
# cs_id: 17
# cs_id: 18
# cs_id: 19
# cs_id: 20
# cs_id: 21
# cs_id: 22
# cs_id: 23
# cs_id: 24
# cs_id: 25

# %%
n_fict_excitation_j = n_fict_excitation_e_j.cs[1]

# %%
n_fict_excitation_j.metadata['cs_id']
# Out:
# 3

# %%
n_fict_excitation_v = nepc.CustomModel(cursor, "fict", filter={'process': 'excitation_v'})

# %%
n_fict_excitation_v.summary()
# Out:
# Number of cross sections in model: 9
# <style  type="text/css" >
#     #T_4475b4b2_99ea_11ea_86fd_acde48001122row0_col6 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row0_col7 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row0_col8 {
#             background-color:  #f0f921;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row0_col9 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row0_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row0_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row1_col6 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row1_col7 {
#             background-color:  #a62098;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row1_col8 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row1_col9 {
#             background-color:  #f0f921;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row1_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row1_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row2_col6 {
#             background-color:  #5502a4;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row2_col7 {
#             background-color:  #c03a83;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row2_col8 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row2_col9 {
#             background-color:  #ef7c51;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row2_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row2_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row3_col6 {
#             background-color:  #8b0aa5;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row3_col7 {
#             background-color:  #d5546e;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row3_col8 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row3_col9 {
#             background-color:  #d6556d;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row3_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row3_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row4_col6 {
#             background-color:  #b83289;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row4_col7 {
#             background-color:  #e76f5a;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row4_col8 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row4_col9 {
#             background-color:  #c7427c;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row4_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row4_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row5_col6 {
#             background-color:  #db5c68;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row5_col7 {
#             background-color:  #f68d45;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row5_col8 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row5_col9 {
#             background-color:  #8e0ca4;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row5_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row5_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row6_col6 {
#             background-color:  #f48849;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row6_col7 {
#             background-color:  #fdae32;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row6_col8 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row6_col9 {
#             background-color:  #9e199d;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row6_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row6_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row7_col6 {
#             background-color:  #febd2a;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row7_col7 {
#             background-color:  #f0f921;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row7_col8 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row7_col9 {
#             background-color:  #6001a6;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row7_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row7_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row8_col6 {
#             background-color:  #f0f921;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row8_col7 {
#             background-color:  #f0f921;
#             color:  #000000;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row8_col8 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row8_col9 {
#             background-color:  #280592;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row8_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4475b4b2_99ea_11ea_86fd_acde48001122row8_col11 {

# %%
n_fict_excitation_e_v_j = nepc.CustomModel(cs_list = [n_fict_excitation_j] + n_fict_excitation_e + n_fict_excitation_v.cs)

# %%
n_fict_excitation_e_v_j.summary()
# Out:
# Number of cross sections in model: 23
# <style  type="text/css" >
#     #T_4496e222_99ea_11ea_86fd_acde48001122row0_col6 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row0_col7 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row0_col8 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row0_col9 {
#             background-color:  #dc5d67;
#             color:  #000000;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row0_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row0_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row1_col6 {
#             background-color:  #c5407e;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row1_col7 {
#             background-color:  #7d03a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row1_col8 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row1_col9 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row1_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row1_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row2_col6 {
#             background-color:  #d45270;
#             color:  #000000;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row2_col7 {
#             background-color:  #7d03a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row2_col8 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row2_col9 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row2_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row2_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row3_col6 {
#             background-color:  #da5a6a;
#             color:  #000000;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row3_col7 {
#             background-color:  #6100a7;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row3_col8 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row3_col9 {
#             background-color:  #240691;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row3_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row3_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row4_col6 {
#             background-color:  #da5a6a;
#             color:  #000000;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row4_col7 {
#             background-color:  #7d03a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row4_col8 {
#             background-color:  #3f049c;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row4_col9 {
#             background-color:  #2a0593;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row4_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row4_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row5_col6 {
#             background-color:  #e16462;
#             color:  #000000;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row5_col7 {
#             background-color:  #8305a7;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row5_col8 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row5_col9 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row5_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row5_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row6_col6 {
#             background-color:  #e66c5c;
#             color:  #000000;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row6_col7 {
#             background-color:  #7501a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row6_col8 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row6_col9 {
#             background-color:  #16078a;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row6_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row6_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row7_col6 {
#             background-color:  #e97257;
#             color:  #000000;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row7_col7 {
#             background-color:  #7501a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row7_col8 {
#             background-color:  #5502a4;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row7_col9 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row7_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row7_col11 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row8_col6 {
#             background-color:  #eb7655;
#             color:  #000000;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row8_col7 {
#             background-color:  #8305a7;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row8_col8 {
#             background-color:  #f0f921;
#             color:  #000000;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row8_col9 {
#             background-color:  #260591;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row8_col10 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#             : ;
#         }    #T_4496e222_99ea_11ea_86fd_acde48001122row8_col11 {

# %%
n_fict_excitation_e_v_j.plot(units_sigma=1E-20,
              plot_param_dict = {'linewidth':.8}, 
              #xlim_param_dict = {'left': 1, 'right': 120.0}, 
              ylog=True, xlog=True, max_plots=40, width=14, height=14)

# %%
e_range = np.logspace(-2, 3, 501)

# %%
sigma = [0.0 for _ in range(len(e_range))]
for e, i in zip(e_range, range(len(e_range))):    
    for cs in n_fict_excitation_e_v_j.cs:
        sigma_i = log_interp(e, cs.data['e'], cs.data['sigma'])
        if ~np.isnan(sigma_i):
            sigma[i] += sigma_i
sigma_nan = np.isnan(sigma)
sigma = np.array(sigma)
e_range = e_range[~sigma_nan]
sigma = sigma[~sigma_nan]
eps = 1E-24
sigma[np.abs(sigma) < eps] = 0.0
# Out:
# /usr/local/anaconda3/envs/nepc/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.

# %%
fict_min_excitation_total = nepc.CustomCS(metadata={'specie': 'N2',
                                                     'process': 'excitation_total',
                                                     'units_e': 1.0,
                                                     'units_sigma': 1.0,
                                                     'ref': '\\N',
                                                     'lhsA': 'N2(X1Sigmag+)',
                                                     'lhsB': None,
                                                     'rhsA': 'N2*',
                                                     'rhsB': None,
                                                     'threshold': 0.02,
                                                     'wavelength': -1.0,
                                                     'lhs_v': -1,
                                                     'rhs_v': -1,
                                                     'lhs_j': -1,
                                                     'rhs_j': -1,
                                                     'background': 'Sum of excitations (electronic, vibrational, and rotational) in fict complete model.',
                                                     'lpu': -1.0,
                                                     'upu': -1.0,
                                                     'lhsA_long': 'N${}_2$ (X ${}^1\\Sigma_g^+$)',
                                                     'lhsB_long': None,
                                                     'rhsA_long': 'N${}_2^*$',
                                                     'rhsB_long': None,
                                                     'e_on_lhs': 1,
                                                     'e_on_rhs': 1,
                                                     'hv_on_lhs': 0,
                                                     'hv_on_rhs': 0,
                                                     'v_on_lhs': 0,
                                                     'v_on_rhs': 0,
                                                     'j_on_lhs': 0,
                                                     'j_on_rhs': 0},
                                            data={'e': list(e_range),
                                                  'sigma': list(sigma)})

# %%
fict_min_excitation_total.plot(units_sigma=1E-20,
              plot_param_dict = {'linewidth':.8}, 
              xlim_param_dict = {'left': .01, 'right': 1000.0}, 
              ylog=True, xlog=True, width=4, height=4)

# %%
n_fict_excitation_e_v_j_total = nepc.CustomModel(
    cs_list=([n_fict_excitation_j] + n_fict_excitation_e + 
             n_fict_excitation_v.cs + [fict_min_excitation_total]))

# %%
n_fict_excitation_e_v_j_total.plot(units_sigma=1E-20,
                                     plot_param_dict = {'linewidth':.8}, 
                                     xlim_param_dict = {'left': .01, 'right': 1000.0}, 
                                     ylog=True, xlog=True, max_plots=40, width=8, height=8)

# %%
data_array = np.asarray([[e_i, sigma_i] for e_i, sigma_i in zip(fict_min_excitation_total.data['e'],
                                                                fict_min_excitation_total.data['sigma'])])

# %%
cs_name = outdir + '/fict_min_excitation_total'
next_csdata_id = parser.write_data_to_file(data_array=data_array,
                                            filename=cs_name+'.dat',
                                            start_csdata_id=next_csdata_id)
next_cs_id = parser.write_metadata_to_file(filename=cs_name+'.met',
                                            cs_id=next_cs_id,
                                            specie=fict_min_excitation_total.metadata['specie'],
                                            process=fict_min_excitation_total.metadata['process'],
                                            lhs_a=fict_min_excitation_total.metadata['lhsA'],
                                            rhs_a=fict_min_excitation_total.metadata['rhsA'],
                                            lhs_v=fict_min_excitation_total.metadata['lhs_v'],
                                            rhs_v=fict_min_excitation_total.metadata['rhs_v'],
                                            units_e=fict_min_excitation_total.metadata['units_e'],
                                            units_sigma=fict_min_excitation_total.metadata['units_sigma'],
                                            threshold=fict_min_excitation_total.metadata['threshold'],
                                            ref=fict_min_excitation_total.metadata['ref'],
                                            background=fict_min_excitation_total.metadata['background'])
parser.write_models_to_file(filename=cs_name+'.mod',
                             models_array=['fict', 'fict_min'])

# %%
e_range = np.logspace(0, 3, 301)

# %%
sigma = [0.0 for _ in range(len(e_range))]
for e, i in zip(e_range, range(len(e_range))):    
    for cs in n_fict_excitation_e:
        sigma_i = log_interp(e, cs.data['e'], cs.data['sigma'])
        if ~np.isnan(sigma_i):
            sigma[i] += sigma_i
sigma_nan = np.isnan(sigma)
sigma = np.array(sigma)
e_range = e_range[~sigma_nan]
sigma = sigma[~sigma_nan]
eps = 1E-24
sigma[np.abs(sigma) < eps] = 0.0
# Out:
# /usr/local/anaconda3/envs/nepc/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.

# %%
fict_min2_excitation_total_e = nepc.CustomCS(metadata={'specie': 'N2',
                                                     'process': 'excitation_total',
                                                     'units_e': 1.0,
                                                     'units_sigma': 1.0,
                                                     'ref': '\\N',
                                                     'lhsA': 'N2(X1Sigmag+)',
                                                     'lhsB': None,
                                                     'rhsA': 'N2*',
                                                     'rhsB': None,
                                                     'threshold': 6.17,
                                                     'wavelength': -1.0,
                                                     'lhs_v': -1,
                                                     'rhs_v': -1,
                                                     'lhs_j': -1,
                                                     'rhs_j': -1,
                                                     'background': 'Sum of electronic excitations in fict complete model.',
                                                     'lpu': -1.0,
                                                     'upu': -1.0,
                                                     'lhsA_long': 'N${}_2$ (X ${}^1\\Sigma_g^+$)',
                                                     'lhsB_long': None,
                                                     'rhsA_long': 'N${}_2^*$',
                                                     'rhsB_long': None,
                                                     'e_on_lhs': 1,
                                                     'e_on_rhs': 1,
                                                     'hv_on_lhs': 0,
                                                     'hv_on_rhs': 0,
                                                     'v_on_lhs': 0,
                                                     'v_on_rhs': 0,
                                                     'j_on_lhs': 0,
                                                     'j_on_rhs': 0},
                                            data={'e': list(e_range),
                                                  'sigma': list(sigma)})

# %%
fict_min2_excitation_total_e.plot(units_sigma=1E-20,
              plot_param_dict = {'linewidth':.8}, 
              xlim_param_dict = {'left': 6, 'right': 1000.0}, 
              ylog=True, xlog=True, width=4, height=4)

# %%
n_fict_min2_excitation_total_e_model = nepc.CustomModel(
    cs_list=(n_fict_excitation_e + [fict_min2_excitation_total_e]))

# %%
n_fict_min2_excitation_total_e_model.plot(units_sigma=1E-20,
                                     plot_param_dict = {'linewidth':.8}, 
                                     xlim_param_dict = {'left': 6, 'right': 1000.0}, 
                                     ylog=True, xlog=True, max_plots=40, width=12, height=12)

# %%
data_array = np.asarray([[e_i, sigma_i] for e_i, sigma_i in zip(fict_min2_excitation_total_e.data['e'],
                                                                fict_min2_excitation_total_e.data['sigma'])])

# %%
cs_name = outdir + '/fict_min2_excitation_total_e'
next_csdata_id = parser.write_data_to_file(data_array=data_array,
                                            filename=cs_name+'.dat',
                                            start_csdata_id=next_csdata_id)
next_cs_id = parser.write_metadata_to_file(filename=cs_name+'.met',
                                            cs_id=next_cs_id,
                                            specie=fict_min2_excitation_total_e.metadata['specie'],
                                            process=fict_min2_excitation_total_e.metadata['process'],
                                            lhs_a=fict_min2_excitation_total_e.metadata['lhsA'],
                                            rhs_a=fict_min2_excitation_total_e.metadata['rhsA'],
                                            lhs_v=fict_min2_excitation_total_e.metadata['lhs_v'],
                                            rhs_v=fict_min2_excitation_total_e.metadata['rhs_v'],
                                            units_e=fict_min2_excitation_total_e.metadata['units_e'],
                                            units_sigma=fict_min2_excitation_total_e.metadata['units_sigma'],
                                            threshold=fict_min2_excitation_total_e.metadata['threshold'],
                                            ref=fict_min2_excitation_total_e.metadata['ref'],
                                            background=fict_min2_excitation_total_e.metadata['background'])
parser.write_models_to_file(filename=cs_name+'.mod',
                             models_array=['fict', 'fict_min2'])

# %%
e_range = np.logspace(-1, 2, 301)

# %%
sigma = [0.0 for _ in range(len(e_range))]
for e, i in zip(e_range, range(len(e_range))):    
    for cs in n_fict_excitation_v.cs:
        sigma_i = log_interp(e, cs.data['e'], cs.data['sigma'])
        if ~np.isnan(sigma_i):
            sigma[i] += sigma_i
sigma_nan = np.isnan(sigma)
sigma = np.array(sigma)
e_range = e_range[~sigma_nan]
sigma = sigma[~sigma_nan]
eps = 1E-24
sigma[np.abs(sigma) < eps] = 0.0
# Out:
# /usr/local/anaconda3/envs/nepc/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.

# %%
fict_min2_excitation_total_v = nepc.CustomCS(metadata={'specie': 'N2',
                                                     'process': 'excitation_total',
                                                     'units_e': 1.0,
                                                     'units_sigma': 1.0,
                                                     'ref': '\\N',
                                                     'lhsA': 'N2(X1Sigmag+)',
                                                     'lhsB': None,
                                                     'rhsA': 'N2(X1Sigmag+)_v1-8)',
                                                     'rhsB': None,
                                                     'threshold': 0.29,
                                                     'wavelength': -1.0,
                                                     'lhs_v': -1,
                                                     'rhs_v': -1,
                                                     'lhs_j': -1,
                                                     'rhs_j': -1,
                                                     'background': 'Sum of vibrational excitations for N2(X) state in fict complete model.',
                                                     'lpu': -1.0,
                                                     'upu': -1.0,
                                                     'lhsA_long': 'N${}_2$ (X ${}^1\\Sigma_g^+$)',
                                                     'lhsB_long': None,
                                                     'rhsA_long': 'N${}_2$ (X ${}^1\Sigma_g^+ v=(1-8)$)',
                                                     'rhsB_long': None,
                                                     'e_on_lhs': 1,
                                                     'e_on_rhs': 1,
                                                     'hv_on_lhs': 0,
                                                     'hv_on_rhs': 0,
                                                     'v_on_lhs': 0,
                                                     'v_on_rhs': 0,
                                                     'j_on_lhs': 0,
                                                     'j_on_rhs': 0},
                                            data={'e': list(e_range),
                                                  'sigma': list(sigma)})

# %%
fict_min2_excitation_total_v.plot(units_sigma=1E-20,
              plot_param_dict = {'linewidth':.8}, 
              xlim_param_dict = {'left': 0.25, 'right': 1000.0}, 
              ylog=True, xlog=True, width=4, height=4)

# %%
n_fict_min2_excitation_total_v_model = nepc.CustomModel(
    cs_list=(n_fict_excitation_v.cs + [fict_min2_excitation_total_v]))

# %%
n_fict_min2_excitation_total_v_model.plot(units_sigma=1E-20,
                                     plot_param_dict = {'linewidth':.8}, 
                                     xlim_param_dict = {'left': .25, 'right': 100.0}, 
                                     ylog=True, xlog=True, max_plots=40, width=12, height=12)

# %%
data_array = np.asarray([[e_i, sigma_i] for e_i, sigma_i in zip(fict_min2_excitation_total_v.data['e'],
                                                                fict_min2_excitation_total_v.data['sigma'])])

# %%
cs_name = outdir + '/fict_min2_excitation_total_v'
next_csdata_id = parser.write_data_to_file(data_array=data_array,
                                            filename=cs_name+'.dat',
                                            start_csdata_id=next_csdata_id)
next_cs_id = parser.write_metadata_to_file(filename=cs_name+'.met',
                                            cs_id=next_cs_id,
                                            specie=fict_min2_excitation_total_v.metadata['specie'],
                                            process=fict_min2_excitation_total_v.metadata['process'],
                                            lhs_a=fict_min2_excitation_total_v.metadata['lhsA'],
                                            rhs_a=fict_min2_excitation_total_v.metadata['rhsA'],
                                            lhs_v=fict_min2_excitation_total_v.metadata['lhs_v'],
                                            rhs_v=fict_min2_excitation_total_v.metadata['rhs_v'],
                                            units_e=fict_min2_excitation_total_v.metadata['units_e'],
                                            units_sigma=fict_min2_excitation_total_v.metadata['units_sigma'],
                                            threshold=fict_min2_excitation_total_v.metadata['threshold'],
                                            ref=fict_min2_excitation_total_v.metadata['ref'],
                                            background=fict_min2_excitation_total_v.metadata['background'])
parser.write_models_to_file(filename=cs_name+'.mod',
                             models_array=['fict', 'fict_min2'])

# %%
parser.write_next_id_to_file(next_cs_id, next_csdata_id, test=True)

# %%
next_cs_id, next_csdata_id
# Out:
# (31, 1682)

# %%
cnx.close()
