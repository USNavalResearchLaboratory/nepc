# %%
import pdfplumber

# %%
pdf = pdfplumber.open("/home/adamson/projects/cs/ref/angus/16_Itikawa_J_Phys_Chem_Ref_Data_35_31_2006.pdf")

# %%
p11 = pdf.pages[10]

# %%
im = p11.to_image()
im.draw_rects(p11.extract_tables(table_settings = { "horizontal_strategy": "text"}))

# %%
table = p11.extract_table(table_settings = {"vertical_strategy": "lines_strict", "horizontal_strategy": "lines_strict"})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-1654d2c8f12e> in <module>
# ----> 1 table = p11.extract_table(table_settings = {"vertical_strategy": "lines_strict", "horizontal_strategy": "lines_strict"})
#
# ~/anaconda3/envs/pcm/lib/python3.7/site-packages/pdfplumber/page.py in extract_table(self, table_settings)
#     183         # Return the largest table, as measured by number of cells.
#     184         sorter = lambda x: (len(x.cells), x.bbox[1], x.bbox[0])
# --> 185         largest = list(sorted(tables, key=sorter))[0]
#     186         return largest.extract()
#     187
#
# IndexError: list index out of range
